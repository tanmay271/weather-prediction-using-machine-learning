# %%
import pandas as pd

# %%
weather = pd.read_csv("local_weather.csv",index_col="time")

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11894 entries, 01-01-1990 to 25-07-2022
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tavg    11800 non-null  float64
#  1   tmin    10358 non-null  float64
#  2   tmax    11361 non-null  float64
#  3   prcp    5754 non-null   float64
# dtypes: float64(4)
# memory usage: 464.6+ KB

# %%
weather.head()
# Out:
#             tavg  tmin  tmax  prcp
# time
# 01-01-1990   9.4   6.0  15.1   0.0
# 02-01-1990   9.3   5.2  14.2   0.0
# 03-01-1990   9.0   6.5  13.6   0.0
# 04-01-1990  10.7   6.0  17.5   0.0
# 05-01-1990  12.6   7.3  20.8   0.0

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# tavg    0.007903
# tmin    0.129141
# tmax    0.044813
# prcp    0.516227
# dtype: float64

# %%
weather["prcp"] = weather["prcp"].fillna(0)
weather = weather.fillna(method="ffill")

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# tavg    0.0
# tmin    0.0
# tmax    0.0
# prcp    0.0
# dtype: float64

# %%
weather.dtypes
# Out:
# tavg    float64
# tmin    float64
# tmax    float64
# prcp    float64
# dtype: object

# %%
weather.index
# Out:
# Index(['01-01-1990', '02-01-1990', '03-01-1990', '04-01-1990', '05-01-1990',
#        '06-01-1990', '07-01-1990', '08-01-1990', '09-01-1990', '10-01-1990',
#        ...
#        '16-07-2022', '17-07-2022', '18-07-2022', '19-07-2022', '20-07-2022',
#        '21-07-2022', '22-07-2022', '23-07-2022', '24-07-2022', '25-07-2022'],
#       dtype='object', name='time', length=11894)

# %%
weather.index = pd.to_datetime(weather.index , dayfirst=True)

# %%
weather.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2022-07-16', '2022-07-17', '2022-07-18', '2022-07-19',
#                '2022-07-20', '2022-07-21', '2022-07-22', '2022-07-23',
#                '2022-07-24', '2022-07-25'],
#               dtype='datetime64[ns]', name='time', length=11894, freq=None)

# %%
weather[["tmax", "tmin"]].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
weather["prcp"].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

     

weather
# Out:
#             tavg  tmin  tmax  prcp  target
# time
# 1990-01-01   9.4   6.0  15.1   0.0    14.2
# 1990-01-02   9.3   5.2  14.2   0.0    13.6
# 1990-01-03   9.0   6.5  13.6   0.0    17.5
# 1990-01-04  10.7   6.0  17.5   0.0    20.8
# 1990-01-05  12.6   7.3  20.8   0.0    22.9
# ...          ...   ...   ...   ...     ...
# 2022-07-21  28.6  26.8  30.6  21.2    32.9
# 2022-07-22  29.3  27.0  32.9   0.3    34.9
# 2022-07-23  30.1  25.5  34.9   8.9    35.7
# 2022-07-24  30.6  27.1  35.7   0.0    35.7
# 2022-07-25  30.7  26.8  35.7   0.0     NaN
#
# [11894 rows x 5 columns]

# %%
weather = weather.iloc[:-1,:].copy()
     

weather
# Out:
#             tavg  tmin  tmax  prcp  target
# time
# 1990-01-01   9.4   6.0  15.1   0.0    14.2
# 1990-01-02   9.3   5.2  14.2   0.0    13.6
# 1990-01-03   9.0   6.5  13.6   0.0    17.5
# 1990-01-04  10.7   6.0  17.5   0.0    20.8
# 1990-01-05  12.6   7.3  20.8   0.0    22.9
# ...          ...   ...   ...   ...     ...
# 2022-07-20  30.1  26.5  33.2  14.7    30.6
# 2022-07-21  28.6  26.8  30.6  21.2    32.9
# 2022-07-22  29.3  27.0  32.9   0.3    34.9
# 2022-07-23  30.1  25.5  34.9   8.9    35.7
# 2022-07-24  30.6  27.1  35.7   0.0    35.7
#
# [11893 rows x 5 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)
     

predictors = ["prcp", "tmax", "tmin"]
     

train = weather.loc[:"2020-12-31"]
test = weather.loc["2021-01-01":]
     

train
# Out:
#             tavg  tmin  tmax  prcp  target
# time
# 1990-01-01   9.4   6.0  15.1   0.0    14.2
# 1990-01-02   9.3   5.2  14.2   0.0    13.6
# 1990-01-03   9.0   6.5  13.6   0.0    17.5
# 1990-01-04  10.7   6.0  17.5   0.0    20.8
# 1990-01-05  12.6   7.3  20.8   0.0    22.9
# ...          ...   ...   ...   ...     ...
# 2020-12-27  15.0   6.0  21.9   0.0    22.6
# 2020-12-28  11.8   5.6  22.6   0.0    20.9
# 2020-12-29  10.8   3.6  20.9   0.0    18.1
# 2020-12-30   9.1   3.5  18.1   0.0    17.0
# 2020-12-31  10.7   3.3  17.0   0.0    18.4
#
# [11323 rows x 5 columns]

# %%
test
# Out:
#             tavg  tmin  tmax  prcp  target
# time
# 2021-01-01  10.4   1.1  18.4   0.0    19.2
# 2021-01-02  12.4   7.0  19.2   0.5    19.5
# 2021-01-03  13.3   9.9  19.5  24.9    22.4
# 2021-01-04  16.8  11.4  22.4  15.0    22.6
# 2021-01-05  17.7  13.2  22.6   5.1    20.8
# ...          ...   ...   ...   ...     ...
# 2022-07-20  30.1  26.5  33.2  14.7    30.6
# 2022-07-21  28.6  26.8  30.6  21.2    32.9
# 2022-07-22  29.3  27.0  32.9   0.3    34.9
# 2022-07-23  30.1  25.5  34.9   8.9    35.7
# 2022-07-24  30.6  27.1  35.7   0.0    35.7
#
# [570 rows x 5 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
     

from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 2.889859802933319

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]
     

combined
# Out:
#             actual  predictions
# time
# 2021-01-01    19.2    18.637096
# 2021-01-02    19.5    19.713956
# 2021-01-03    22.4    20.420926
# 2021-01-04    22.6    23.015244
# 2021-01-05    20.8    23.195190
# ...            ...          ...
# 2022-07-20    30.6    33.638610
# 2022-07-21    32.9    31.384729
# 2022-07-22    34.9    33.242110
# 2022-07-23    35.7    35.047718
# 2022-07-24    35.7    35.767096
#
# [570 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
reg.coef_
# Out:
# array([0.01083208, 0.90081784, 0.05945583])

# %%
def create_predictions(predictors,weather,reg):
  train = weather.loc[:"2020-12-31"]
  test = weather.loc["2021-01-01":]
  reg.fit(train[predictors], train["target"])
  predictions = reg.predict(test[predictors])
  error = mean_squared_error(test["target"], predictions)
  combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
  combined.columns = ["actual", "predictions"]
  return error,combined
     

weather["month_day_max"] = weather["tavg"] / weather["tmax"]

weather["max_min"] = weather["tmax"] / weather["tmin"]
     

predictors = ["prcp", "tmax", "tmin", "month_day_max", "max_min"]

error, combined = create_predictions(predictors, weather, reg)
error
# Out:
# 2.5638100745857595

# %%
combined
# Out:
#             actual  predictions
# time
# 2021-01-01    19.2    18.314273
# 2021-01-02    19.5    19.450843
# 2021-01-03    22.4    19.951499
# 2021-01-04    22.6    23.410767
# 2021-01-05    20.8    23.728848
# ...            ...          ...
# 2022-07-20    30.6    33.931081
# 2022-07-21    32.9    31.732538
# 2022-07-22    34.9    33.278048
# 2022-07-23    35.7    35.139101
# 2022-07-24    35.7    35.582482
#
# [570 rows x 2 columns]

# %%
weekpredict = combined.iloc[:30]
     

weekpredict
# Out:
#             actual  predictions
# time
# 2021-01-01    19.2    18.314273
# 2021-01-02    19.5    19.450843
# 2021-01-03    22.4    19.951499
# 2021-01-04    22.6    23.410767
# 2021-01-05    20.8    23.728848
# 2021-01-06    21.3    22.801098
# 2021-01-07    19.9    21.854057
# 2021-01-08    19.6    20.262158
# 2021-01-09    19.7    21.119600
# 2021-01-10    16.8    19.160325
# 2021-01-11    17.5    17.897852
# 2021-01-12    17.6    15.417216
# 2021-01-13    19.0    17.161398
# 2021-01-14    20.0    19.838785
# 2021-01-15    20.8    19.659723
# 2021-01-16    19.1    19.875041
# 2021-01-17    19.4    18.760174
# 2021-01-18    20.2    20.944424
# 2021-01-19    20.4    20.668965
# 2021-01-20    22.8    20.469086
# 2021-01-21    22.8    22.460577
# 2021-01-22    20.0    21.869262
# 2021-01-23    20.4    20.665471
# 2021-01-24    17.4    19.167330
# 2021-01-25    20.2    18.043170
# 2021-01-26    20.8    20.575298
# 2021-01-27    21.5    20.408170
# 2021-01-28    20.4    20.639404
# 2021-01-29    21.2    20.093542
# 2021-01-30    23.8    21.388472

# %%
weekpredict.plot()
# Out:
# <AxesSubplot:xlabel='time'>
